# %%
import sys
import os

project_root = os.path.abspath("..")
sys.path.append(project_root)

import pandas as pd
from config import DATA_PATH
from Data.raw_data_loader import load_raw_crypto_csv

df = load_raw_crypto_csv(DATA_PATH)

print("Data loaded:", df.shape)
# Out:
# Data loaded: (6613, 12)

# %%
eth_price.index = pd.to_datetime(eth_price.index)
eth_price = eth_price.loc["2017-11-12":]

eth_ret = eth_price.pct_change().dropna()

print("ETH Annualized Vol:", eth_ret.std() * (365 ** 0.5))
print("ETH CAGR:", (eth_price.iloc[-1] / eth_price.iloc[0]) ** (365 / len(eth_price)) - 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 eth_price.index = pd.to_datetime(eth_price.index)
#       2 eth_price = eth_price.loc["2017-11-12":]
#       4 eth_ret = eth_price.pct_change().dropna()
#
# NameError: name 'eth_price' is not defined

# %%
z_pos = zscore_signal(
    df,
    price_column="ETH-USD_close",
)

trend_pos = trend_signal(
    df,
    price_column="ETH-USD_close",
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 z_pos = zscore_signal(
#       2     df,
#       3     price_column="ETH-USD_close",
#       4 )
#       6 trend_pos = trend_signal(
#       7     df,
#       8     price_column="ETH-USD_close",
#       9 )
#
# NameError: name 'zscore_signal' is not defined

# %%
eth_price = df["ETH-USD_close"].astype(float)

z_results = run_backtest(
    price_series=eth_price,
    position=z_pos,
    fee_bps=FEE_BPS,
    slippage_bps=SLIPPAGE_BPS,
    annual_borrow_rate=ANNUAL_BORROW_RATE,
    leverage_cap=LEVERAGE_CAP,
)

trend_results = run_backtest(
    price_series=eth_price,
    position=trend_pos,
    fee_bps=FEE_BPS,
    slippage_bps=SLIPPAGE_BPS,
    annual_borrow_rate=ANNUAL_BORROW_RATE,
    leverage_cap=LEVERAGE_CAP,
)

# %%
summary = build_summary_table({
    "Z-Score": {"returns": z_results["net_returns"], "position": z_pos},
    "Trend": {"returns": trend_results["net_returns"], "position": trend_pos},
})
summary
