# %%
import sys
import os

project_root = os.path.abspath("..")
sys.path.append(project_root)

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from config import *
from Data.raw_data_loader import (
    load_raw_crypto_csv,
    basic_data_diagnostics,
    check_constant_stretches,
)
from Models.pair_trading import build_spread, adf_test

plt.style.use("default")

# %%
df = load_raw_crypto_csv(DATA_PATH)

print("Data shape: ", df.shape)
print("Start:", df.index.min())
print("End:", df.index.max())

df.head()
# Out:
# Data shape:  (6613, 12)
# Start: 2008-01-01 00:00:00
# End: 2026-02-10 00:00:00
#             BTC-USD_open  BTC-USD_high  BTC-USD_low  BTC-USD_close  \
# Date
# 2008-01-01    456.859985    456.859985   413.104004     424.440002
# 2008-01-02    456.859985    456.859985   413.104004     424.440002
# 2008-01-03    456.859985    456.859985   413.104004     424.440002
# 2008-01-04    456.859985    456.859985   413.104004     424.440002
# 2008-01-05    456.859985    456.859985   413.104004     424.440002
#
#             BTC-USD_volume  BTC_REWARD  COST_TO_MINE  ETH-USD_open  \
# Date
# 2008-01-01      34483200.0        50.0      177.2767    314.690002
# 2008-01-02      34483200.0        50.0      177.2767    314.690002
# 2008-01-03      34483200.0        50.0      177.2767    314.690002
# 2008-01-04      34483200.0        50.0      177.2767    314.690002
# 2008-01-05      34483200.0        50.0      177.2767    314.690002
#
#             ETH-USD_high  ETH-USD_low  ETH-USD_close  ETH-USD_volume
# Date
# 2008-01-01    319.153015      298.513     307.907989    1.613480e+09
# 2008-01-02    319.153015      298.513     307.907989    1.613480e+09
# 2008-01-03    319.153015      298.513     307.907989    1.613480e+09
# 2008-01-04    319.153015      298.513     307.907989    1.613480e+09
# 2008-01-05    319.153015      298.513     307.907989    1.613480e+09

# %%
diagnostics = basic_data_diagnostics(df)
diagnostics
# Out:
# {'start_date': Timestamp('2008-01-01 00:00:00'),
#  'end_date': Timestamp('2026-02-10 00:00:00'),
#  'n_rows': 6613,
#  'n_missing': np.int64(0),
#  'btc_zero_volume_days': 0,
#  'eth_zero_volume_days': 0,
#  'duplicate_index': 0}

# %%
df0 = df.copy()

# Only keep period where ETH actually exists and both prices are positive
df0 = df0[(df0["BTC-USD_close"] > 0) & (df0["ETH-USD_close"] > 0)]

# ETH realistically starts ~2015; choose 2016+ to be safe and comparable
df0 = df0.loc["2016-01-01":].copy()

# Remove obvious price spikes using return-based filtering (robust)
btc_ret0 = df0["BTC-USD_close"].pct_change()
eth_ret0 = df0["ETH-USD_close"].pct_change()

# Drop days with absurd daily moves (data errors). You can tighten/loosen these.
btc_bad = btc_ret0.abs() > 1.0      # > 100% in a day
eth_bad = eth_ret0.abs() > 2.0      # > 200% in a day (ETH can be wilder)

df0 = df0[~(btc_bad | eth_bad)].copy()

print("Filtered shape:", df0.shape)
print("Start:", df0.index.min(), "End:", df0.index.max())
# Out:
# Filtered shape: (3690, 12)
# Start: 2016-01-01 00:00:00 End: 2026-02-09 00:00:00

# %%
plt.figure(figsize=(12,5))
plt.plot(df0.index, df0["BTC-USD_close"], label="BTC")
plt.plot(df0.index, df0["ETH-USD_close"], label="ETH")
plt.yscale("log")
plt.title("BTC vs ETH Price (log y-scale, filtered)")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,5))
plt.plot(df0.index, np.log(df0["BTC-USD_close"]), label="log BTC")
plt.plot(df0.index, np.log(df0["ETH-USD_close"]), label="log ETH")
plt.title("Log Prices (filtered)")
plt.legend()
plt.show()

# %%
btc_ret = df0["BTC-USD_close"].pct_change().dropna()
eth_ret = df0["ETH-USD_close"].pct_change().dropna()

print("BTC annualized vol:", float(btc_ret.std() * np.sqrt(365)))
print("ETH annualized vol:", float(eth_ret.std() * np.sqrt(365)))

corr = float(btc_ret.corr(eth_ret))
print("BTC–ETH daily return correlation:", corr)
# Out:
# BTC annualized vol: 0.6700156610477671
# ETH annualized vol: 0.8018998563139621
# BTC–ETH daily return correlation: 0.6878041721630858

# %%
rolling_corr = btc_ret.rolling(180).corr(eth_ret)

plt.figure(figsize=(12,5))
plt.plot(rolling_corr.index, rolling_corr)
plt.ylim(-1, 1)
plt.title("Rolling 180-Day BTC–ETH Correlation (filtered)")
plt.show()

# %%
btc_vol = btc_ret.rolling(180).std() * np.sqrt(365)
eth_vol = eth_ret.rolling(180).std() * np.sqrt(365)

plt.figure(figsize=(12,5))
plt.plot(btc_vol.index, btc_vol, label="BTC Vol")
plt.plot(eth_vol.index, eth_vol, label="ETH Vol")
plt.title("Rolling 180-Day Annualized Volatility (filtered)")
plt.legend()
plt.show()

# %%
from Models.pair_trading import build_spread, adf_test

spread = build_spread(df0, window=PAIR_BETA_WINDOW)

plt.figure(figsize=(12,5))
plt.plot(spread.index, spread)
plt.title("BTC–ETH Log Spread (filtered)")
plt.show()

spread_z = (spread - spread.rolling(365).mean()) / spread.rolling(365).std()

plt.figure(figsize=(12,5))
plt.plot(spread_z.index, spread_z)
plt.axhline(2, linestyle="--")
plt.axhline(-2, linestyle="--")
plt.title("Spread Z-Score (rolling 365, filtered)")
plt.show()

adf_results = adf_test(spread.dropna())
adf_results
# Out:
# {'ADF_stat': -4.5801947242210606,
#  'p_value': 0.00014047354286518557,
#  'n_lags': 29,
#  'n_obs': 2978}
